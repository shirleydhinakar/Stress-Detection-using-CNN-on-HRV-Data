# %%
import pandas as pd
import numpy as np
import io
import requests
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# %% [markdown]
# # EDA

# %%
url = "https://media.githubusercontent.com/media/shirleydhinakar/Wesad_HRV_Dataset/main/wesad-chest-combined-classification-hrv.csv"
read_data = requests.get(url).content
df = pd.read_csv(io.StringIO(read_data.decode('utf-8')))
df.sample(5)
# Out:
#             MEAN_RR    MEDIAN_RR        SDRR      RMSSD       SDSD  \
# 65816    697.464703   687.525525   85.991171  21.286280  21.284479
# 64175    890.439808   890.946510  121.749342  29.883232  29.877125
# 39345   1305.254170  1181.686350  403.017773  20.454813  20.451795
# 112016   989.748528   988.091435   45.095202   8.731386   8.724781
# 36828    840.523857   837.345125   77.147272  15.989895  15.989886
#
#         SDRR_RMSSD         HR  pNN25  pNN50        SD1  ...  \
# 65816     4.039746  87.271768  24.75   1.50  15.069295  ...
# 64175     4.074169  68.731563  43.00  10.50  21.152842  ...
# 39345    19.702833  50.770902  20.50   2.50  14.479759  ...
# 112016    5.164724  60.746338   0.00   0.00   6.177097  ...
# 36828     4.824752  71.982215  11.50   0.75  11.320752  ...
#
#         MEAN_RR_MEAN_MEAN_REL_RR    SD2_LF     HR_LF       HR_HF    HF_VLF  \
# 65816               1.377107e+06  0.038547  0.027877    1.081497  0.107186
# 64175              -1.043698e+06  0.037404  0.015045    3.215771  0.009131
# 39345               3.699013e+06  1.799772  0.160374  109.240681  0.000062
# 112016             -2.907569e+06  0.315148  0.301603   88.866167  0.000720
# 36828               1.348428e+07  0.115654  0.076719    3.223044  0.006251
#
#         subject id  condition  SSSQ class  SSSQ Label  condition label
# 65816            7     stress      medium           1                2
# 64175           17   baseline         low           0                0
# 39345            2  amusement      medium           1                1
# 112016           5   baseline        high           2                0
# 36828            7   baseline         low           0                0
#
# [5 rows x 67 columns]

# %%
df = df[["HR", "LF_BOXCOX", "MEDIAN_RR", "SD1_BOXCOX","SDRR_REL_RR", "condition", "condition label"]]

# %%
df.sample(5)
# Out:
#                HR   LF_BOXCOX    MEDIAN_RR  SD1_BOXCOX  SDRR_REL_RR condition  \
# 26894   76.560318   44.295683   802.036345   13.232313     0.018441    stress
# 7071    71.868940    7.791453   830.516945    1.711343     0.018062  baseline
# 119524  60.659706   45.689956   992.473250   23.661197     0.020299  baseline
# 108697  67.486288    1.424710   893.704400    0.928232     0.011005  baseline
# 53099   55.850007  487.103396  1079.648600  351.075804     0.026035  baseline
#
#         condition label
# 26894                 2
# 7071                  0
# 119524                0
# 108697                0
# 53099                 0

# %%
df[['condition','condition label']].value_counts()
# Out:
# condition  condition label
# baseline   0                  71640
# stress     2                  40946
# amusement  1                  23064
# dtype: int64

# %%
df.describe()
# Out:
#              MEAN_RR      MEDIAN_RR           SDRR          RMSSD  \
# count  135650.000000  135650.000000  135650.000000  135650.000000
# mean      788.515184     786.845673      71.453748      14.379418
# std       156.334847     160.113990      33.646350       6.134973
# min       411.068840     411.966595      13.786706       2.294390
# 25%       695.450860     689.389645      51.839395       9.579017
# 50%       798.200622     797.564400      65.238376      13.578235
# 75%       888.053029     892.774831      86.848219      18.170919
# max      1341.611513    1181.686350     418.066612      34.881131
#
#                 SDSD     SDRR_RMSSD             HR          pNN25  \
# count  135650.000000  135650.000000  135650.000000  135650.000000
# mean       14.376136       5.247878      80.203812      10.396622
# std         6.134411       1.792526      17.913204      10.857041
# min         2.292144       1.887603      48.183943       0.000000
# 25%         9.576334       4.025865      68.227916       2.000000
# 50%        13.576345       5.028439      75.988575       6.500000
# 75%        18.165098       6.001586      86.975168      15.500000
# max        34.880732      22.194700     146.191044      46.750000
#
#                pNN50            SD1  ...   KURT_SQUARE        HR_SQRT  \
# count  135650.000000  135650.000000  ...  1.356500e+05  135650.000000
# mean        1.026915      10.178226  ...  1.357090e+00       8.904329
# std         1.865541       4.343130  ...  5.323943e+00       0.957470
# min         0.000000       1.622825  ...  3.871992e-10       6.941465
# 25%         0.000000       6.779992  ...  6.322669e-02       8.260019
# 50%         0.000000       9.611978  ...  2.536286e-01       8.717143
# 75%         1.250000      12.860790  ...  7.131422e-01       9.326048
# max        11.500000      24.695368  ...  2.459810e+02      12.090949
#
#        MEAN_RR_MEAN_MEAN_REL_RR         SD2_LF          HR_LF          HR_HF  \
# count              1.356500e+05  135650.000000  135650.000000  135650.000000
# mean              -1.761317e+06       0.166589       0.210475       8.309048
# std                1.070482e+09       0.207166       0.469279      14.892431
# min               -3.426834e+11       0.021295       0.008200       0.294702
# 25%               -3.607337e+06       0.073939       0.048338       2.251744
# 50%               -9.391674e+05       0.111455       0.092320       4.213662
# 75%                3.286467e+06       0.184950       0.203164       8.530982
# max                1.092115e+11       4.771071       9.714187     537.538316
#
#               HF_VLF     subject id     SSSQ Label  condition label
# count  135650.000000  135650.000000  135650.000000    135650.000000
# mean        0.041303       9.398349       0.875245         0.773727
# std         0.081219       4.709621       0.780052         0.882485
# min         0.000009       2.000000       0.000000         0.000000
# 25%         0.005567       5.000000       0.000000         0.000000
# 50%         0.014356       9.000000       1.000000         0.000000
# 75%         0.042999      14.000000       1.000000         2.000000
# max         1.129262      17.000000       2.000000         2.000000
#
# [8 rows x 65 columns]

# %%
# df = df.sample(1000)

# %%
df.shape
# Out:
# (135650, 67)

# %%
df.columns
# Out:
# Index(['MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR',
#        'pNN25', 'pNN50', 'SD1', 'SD2', 'KURT', 'SKEW', 'MEAN_REL_RR',
#        'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR',
#        'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR', 'VLF', 'VLF_PCT',
#        'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF',
#        'HF_LF', 'MEAN_RR_LOG', 'MEAN_RR_SQRT', 'TP_SQRT', 'MEDIAN_REL_RR_LOG',
#        'RMSSD_REL_RR_LOG', 'SDSD_REL_RR_LOG', 'VLF_LOG', 'LF_LOG', 'HF_LOG',
#        'TP_LOG', 'LF_HF_LOG', 'RMSSD_LOG', 'SDRR_RMSSD_LOG', 'pNN25_LOG',
#        'pNN50_LOG', 'SD1_LOG', 'KURT_YEO_JONSON', 'SKEW_YEO_JONSON',
#        'MEAN_REL_RR_YEO_JONSON', 'SKEW_REL_RR_YEO_JONSON', 'LF_BOXCOX',
#        'HF_BOXCOX', 'SD1_BOXCOX', 'KURT_SQUARE', 'HR_SQRT',
#        'MEAN_RR_MEAN_MEAN_REL_RR', 'SD2_LF', 'HR_LF', 'HR_HF', 'HF_VLF',
#        'subject id', 'condition', 'SSSQ class', 'SSSQ Label',
#        'condition label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135650 entries, 0 to 135649
# Data columns (total 67 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   MEAN_RR                   135650 non-null  float64
#  1   MEDIAN_RR                 135650 non-null  float64
#  2   SDRR                      135650 non-null  float64
#  3   RMSSD                     135650 non-null  float64
#  4   SDSD                      135650 non-null  float64
#  5   SDRR_RMSSD                135650 non-null  float64
#  6   HR                        135650 non-null  float64
#  7   pNN25                     135650 non-null  float64
#  8   pNN50                     135650 non-null  float64
#  9   SD1                       135650 non-null  float64
#  10  SD2                       135650 non-null  float64
#  11  KURT                      135650 non-null  float64
#  12  SKEW                      135650 non-null  float64
#  13  MEAN_REL_RR               135650 non-null  float64
#  14  MEDIAN_REL_RR             135650 non-null  float64
#  15  SDRR_REL_RR               135650 non-null  float64
#  16  RMSSD_REL_RR              135650 non-null  float64
#  17  SDSD_REL_RR               135650 non-null  float64
#  18  SDRR_RMSSD_REL_RR         135650 non-null  float64
#  19  KURT_REL_RR               135650 non-null  float64
#  20  SKEW_REL_RR               135650 non-null  float64
#  21  VLF                       135650 non-null  float64
#  22  VLF_PCT                   135650 non-null  float64
#  23  LF                        135650 non-null  float64
#  24  LF_PCT                    135650 non-null  float64
#  25  LF_NU                     135650 non-null  float64
#  26  HF                        135650 non-null  float64
#  27  HF_PCT                    135650 non-null  float64
#  28  HF_NU                     135650 non-null  float64
#  29  TP                        135650 non-null  float64
#  30  LF_HF                     135650 non-null  float64
#  31  HF_LF                     135650 non-null  float64
#  32  MEAN_RR_LOG               135650 non-null  float64
#  33  MEAN_RR_SQRT              135650 non-null  float64
#  34  TP_SQRT                   135650 non-null  float64
#  35  MEDIAN_REL_RR_LOG         135650 non-null  float64
#  36  RMSSD_REL_RR_LOG          135650 non-null  float64
#  37  SDSD_REL_RR_LOG           135650 non-null  float64
#  38  VLF_LOG                   135650 non-null  float64
#  39  LF_LOG                    135650 non-null  float64
#  40  HF_LOG                    135650 non-null  float64
#  41  TP_LOG                    135650 non-null  float64
#  42  LF_HF_LOG                 135650 non-null  float64
#  43  RMSSD_LOG                 135650 non-null  float64
#  44  SDRR_RMSSD_LOG            135650 non-null  float64
#  45  pNN25_LOG                 135650 non-null  float64
#  46  pNN50_LOG                 135650 non-null  float64
#  47  SD1_LOG                   135650 non-null  float64
#  48  KURT_YEO_JONSON           135650 non-null  float64
#  49  SKEW_YEO_JONSON           135650 non-null  float64
#  50  MEAN_REL_RR_YEO_JONSON    135650 non-null  float64
#  51  SKEW_REL_RR_YEO_JONSON    135650 non-null  float64
#  52  LF_BOXCOX                 135650 non-null  float64
#  53  HF_BOXCOX                 135650 non-null  float64
#  54  SD1_BOXCOX                135650 non-null  float64
#  55  KURT_SQUARE               135650 non-null  float64
#  56  HR_SQRT                   135650 non-null  float64
#  57  MEAN_RR_MEAN_MEAN_REL_RR  135650 non-null  float64
#  58  SD2_LF                    135650 non-null  float64
#  59  HR_LF                     135650 non-null  float64
#  60  HR_HF                     135650 non-null  float64
#  61  HF_VLF                    135650 non-null  float64
#  62  subject id                135650 non-null  int64
#  63  condition                 135650 non-null  object
#  64  SSSQ class                135650 non-null  object
#  65  SSSQ Label                135650 non-null  int64
#  66  condition label           135650 non-null  int64
# dtypes: float64(62), int64(3), object(2)
# memory usage: 69.3+ MB

# %%
df.describe()
# Out:
#              MEAN_RR      MEDIAN_RR           SDRR          RMSSD  \
# count  135650.000000  135650.000000  135650.000000  135650.000000
# mean      788.515184     786.845673      71.453748      14.379418
# std       156.334847     160.113990      33.646350       6.134973
# min       411.068840     411.966595      13.786706       2.294390
# 25%       695.450860     689.389645      51.839395       9.579017
# 50%       798.200622     797.564400      65.238376      13.578235
# 75%       888.053029     892.774831      86.848219      18.170919
# max      1341.611513    1181.686350     418.066612      34.881131
#
#                 SDSD     SDRR_RMSSD             HR          pNN25  \
# count  135650.000000  135650.000000  135650.000000  135650.000000
# mean       14.376136       5.247878      80.203812      10.396622
# std         6.134411       1.792526      17.913204      10.857041
# min         2.292144       1.887603      48.183943       0.000000
# 25%         9.576334       4.025865      68.227916       2.000000
# 50%        13.576345       5.028439      75.988575       6.500000
# 75%        18.165098       6.001586      86.975168      15.500000
# max        34.880732      22.194700     146.191044      46.750000
#
#                pNN50            SD1  ...   KURT_SQUARE        HR_SQRT  \
# count  135650.000000  135650.000000  ...  1.356500e+05  135650.000000
# mean        1.026915      10.178226  ...  1.357090e+00       8.904329
# std         1.865541       4.343130  ...  5.323943e+00       0.957470
# min         0.000000       1.622825  ...  3.871992e-10       6.941465
# 25%         0.000000       6.779992  ...  6.322669e-02       8.260019
# 50%         0.000000       9.611978  ...  2.536286e-01       8.717143
# 75%         1.250000      12.860790  ...  7.131422e-01       9.326048
# max        11.500000      24.695368  ...  2.459810e+02      12.090949
#
#        MEAN_RR_MEAN_MEAN_REL_RR         SD2_LF          HR_LF          HR_HF  \
# count              1.356500e+05  135650.000000  135650.000000  135650.000000
# mean              -1.761317e+06       0.166589       0.210475       8.309048
# std                1.070482e+09       0.207166       0.469279      14.892431
# min               -3.426834e+11       0.021295       0.008200       0.294702
# 25%               -3.607337e+06       0.073939       0.048338       2.251744
# 50%               -9.391674e+05       0.111455       0.092320       4.213662
# 75%                3.286467e+06       0.184950       0.203164       8.530982
# max                1.092115e+11       4.771071       9.714187     537.538316
#
#               HF_VLF     subject id     SSSQ Label  condition label
# count  135650.000000  135650.000000  135650.000000    135650.000000
# mean        0.041303       9.398349       0.875245         0.773727
# std         0.081219       4.709621       0.780052         0.882485
# min         0.000009       2.000000       0.000000         0.000000
# 25%         0.005567       5.000000       0.000000         0.000000
# 50%         0.014356       9.000000       1.000000         0.000000
# 75%         0.042999      14.000000       1.000000         2.000000
# max         1.129262      17.000000       2.000000         2.000000
#
# [8 rows x 65 columns]

# %%
df.isnull().sum()
# Out:
# MEAN_RR            0
# MEDIAN_RR          0
# SDRR               0
# RMSSD              0
# SDSD               0
#                   ..
# subject id         0
# condition          0
# SSSQ class         0
# SSSQ Label         0
# condition label    0
# Length: 67, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# MEAN_RR            0
# MEDIAN_RR          0
# SDRR               0
# RMSSD              0
# SDSD               0
#                   ..
# subject id         0
# condition          0
# SSSQ class         0
# SSSQ Label         0
# condition label    0
# Length: 67, dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
def null_percentage(column):
    df_name = column.name
    nans = np.count_nonzero(column.isnull().values)
    total = column.size
    frac = nans / total
    perc = int(frac * 100)
    print('%d%% or %d missing values from [ %s ] column.' % (perc, nans, df_name))

def check_nan(df):
    columns = df.columns
    for col in columns:
      null_percentage(df[col])

# %%
check_nan(df)
# Out:
# 0% or 0 missing values from [ MEAN_RR ] column.
# 0% or 0 missing values from [ MEDIAN_RR ] column.
# 0% or 0 missing values from [ SDRR ] column.
# 0% or 0 missing values from [ RMSSD ] column.
# 0% or 0 missing values from [ SDSD ] column.
# 0% or 0 missing values from [ SDRR_RMSSD ] column.
# 0% or 0 missing values from [ HR ] column.
# 0% or 0 missing values from [ pNN25 ] column.
# 0% or 0 missing values from [ pNN50 ] column.
# 0% or 0 missing values from [ SD1 ] column.
# 0% or 0 missing values from [ SD2 ] column.
# 0% or 0 missing values from [ KURT ] column.
# 0% or 0 missing values from [ SKEW ] column.
# 0% or 0 missing values from [ MEAN_REL_RR ] column.
# 0% or 0 missing values from [ MEDIAN_REL_RR ] column.
# 0% or 0 missing values from [ SDRR_REL_RR ] column.
# 0% or 0 missing values from [ RMSSD_REL_RR ] column.
# 0% or 0 missing values from [ SDSD_REL_RR ] column.
# 0% or 0 missing values from [ SDRR_RMSSD_REL_RR ] column.
# 0% or 0 missing values from [ KURT_REL_RR ] column.
# 0% or 0 missing values from [ SKEW_REL_RR ] column.
# 0% or 0 missing values from [ VLF ] column.
# 0% or 0 missing values from [ VLF_PCT ] column.
# 0% or 0 missing values from [ LF ] column.
# 0% or 0 missing values from [ LF_PCT ] column.
# 0% or 0 missing values from [ LF_NU ] column.
# 0% or 0 missing values from [ HF ] column.
# 0% or 0 missing values from [ HF_PCT ] column.
# 0% or 0 missing values from [ HF_NU ] column.
# 0% or 0 missing values from [ TP ] column.
# 0% or 0 missing values from [ LF_HF ] column.
# 0% or 0 missing values from [ HF_LF ] column.
# 0% or 0 missing values from [ MEAN_RR_LOG ] column.
# 0% or 0 missing values from [ MEAN_RR_SQRT ] column.
# 0% or 0 missing values from [ TP_SQRT ] column.
# 0% or 0 missing values from [ MEDIAN_REL_RR_LOG ] column.
# 0% or 0 missing values from [ RMSSD_REL_RR_LOG ] column.
# 0% or 0 missing values from [ SDSD_REL_RR_LOG ] column.
# 0% or 0 missing values from [ VLF_LOG ] column.
# 0% or 0 missing values from [ LF_LOG ] column.
# 0% or 0 missing values from [ HF_LOG ] column.
# 0% or 0 missing values from [ TP_LOG ] column.
# 0% or 0 missing values from [ LF_HF_LOG ] column.
# 0% or 0 missing values from [ RMSSD_LOG ] column.
# 0% or 0 missing values from [ SDRR_RMSSD_LOG ] column.
# 0% or 0 missing values from [ pNN25_LOG ] column.
# 0% or 0 missing values from [ pNN50_LOG ] column.
# 0% or 0 missing values from [ SD1_LOG ] column.
# 0% or 0 missing values from [ KURT_YEO_JONSON ] column.
# 0% or 0 missing values from [ SKEW_YEO_JONSON ] column.
# 0% or 0 missing values from [ MEAN_REL_RR_YEO_JONSON ] column.
# 0% or 0 missing values from [ SKEW_REL_RR_YEO_JONSON ] column.
# 0% or 0 missing values from [ LF_BOXCOX ] column.
# 0% or 0 missing values from [ HF_BOXCOX ] column.
# 0% or 0 missing values from [ SD1_BOXCOX ] column.
# 0% or 0 missing values from [ KURT_SQUARE ] column.
# 0% or 0 missing values from [ HR_SQRT ] column.
# 0% or 0 missing values from [ MEAN_RR_MEAN_MEAN_REL_RR ] column.
# 0% or 0 missing values from [ SD2_LF ] column.
# 0% or 0 missing values from [ HR_LF ] column.
# 0% or 0 missing values from [ HR_HF ] column.
# 0% or 0 missing values from [ HF_VLF ] column.
# 0% or 0 missing values from [ subject id ] column.
# 0% or 0 missing values from [ condition ] column.
# 0% or 0 missing values from [ SSSQ class ] column.
# 0% or 0 missing values from [ SSSQ Label ] column.
# 0% or 0 missing values from [ condition label ] column.

# %%
num_df = df._get_numeric_data()
obj_df = df.select_dtypes(include=['object'])
print(num_df.shape, obj_df.shape, df.shape)
# Out:
# (135650, 65) (135650, 2) (135650, 67)

# %% [markdown]
# # DATA IMABALANCE

# %%
df[['condition label','condition']].value_counts()
# Out:
# condition label  condition
# 0                baseline     71640
# 2                stress       40946
# 1                amusement    23064
# dtype: int64

# %%
sns.histplot(x = df["condition label"], data = df["condition label"], hue= df["condition label"])
# Out:
# <Axes: xlabel='condition label', ylabel='Count'>

# %%
plt.figure(figsize=(5, 5))
sns.violinplot(df["condition label"])
plt.show()

# %% [markdown]
# # CORRELATION

# %%
corr = num_df.corr()

# %%
plt.figure(figsize=(12, 16))
sns.heatmap(corr, cmap = "coolwarm")
plt.show()

# %%
filteredCorr = corr[((corr >= .75) | (corr <= -.75)) & (corr !=1.000)]
filteredCorr.unstack().sort_values().drop_duplicates()
# Out:
# HR         MEDIAN_RR    -0.959569
# LF_BOXCOX  SD1_BOXCOX    0.960976
# HR         HR                 NaN
# dtype: float64

# %%
filteredDf = corr[((corr >= .5) | (corr <= -.5)) & (corr !=1.000)]
plt.figure(figsize=(30,10))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.show()

# %%
filteredDf.shape, filteredCorr.shape
# Out:
# ((6, 6), (6, 6))

# %%
plt.figure(figsize=(30, 10))
num_df.boxplot()
plt.xlabel('Value')
plt.ylabel('Variable')
plt.title('Distribution of Variables')
plt.grid(alpha=1)
plt.show()

# %%
Q1 = num_df.quantile(0.25)
Q3 = num_df.quantile(0.75)
IQR = Q3 - Q1
outliers = ((num_df < (Q1 - 1.5 * IQR)) | (num_df > (Q3 + 1.5 * IQR)))

# Filter columns with outliers
columns_with_outliers = outliers.any()

# Create boxplots for columns with outliers using Seaborn
for column in columns_with_outliers.index:
    if columns_with_outliers[column]:
        plt.figure(figsize=(4, 3))
        sns.boxplot(data=df, x=column)
        plt.title(f'Boxplot for {column}')
        plt.show()

# %%
num_df.shape
# Out:
# (135650, 65)

# %%
num_df.columns
# Out:
# Index(['MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR',
#        'pNN25', 'pNN50', 'SD1', 'SD2', 'KURT', 'SKEW', 'MEAN_REL_RR',
#        'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR',
#        'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR', 'VLF', 'VLF_PCT',
#        'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF',
#        'HF_LF', 'MEAN_RR_LOG', 'MEAN_RR_SQRT', 'TP_SQRT', 'MEDIAN_REL_RR_LOG',
#        'RMSSD_REL_RR_LOG', 'SDSD_REL_RR_LOG', 'VLF_LOG', 'LF_LOG', 'HF_LOG',
#        'TP_LOG', 'LF_HF_LOG', 'RMSSD_LOG', 'SDRR_RMSSD_LOG', 'pNN25_LOG',
#        'pNN50_LOG', 'SD1_LOG', 'KURT_YEO_JONSON', 'SKEW_YEO_JONSON',
#        'MEAN_REL_RR_YEO_JONSON', 'SKEW_REL_RR_YEO_JONSON', 'LF_BOXCOX',
#        'HF_BOXCOX', 'SD1_BOXCOX', 'KURT_SQUARE', 'HR_SQRT',
#        'MEAN_RR_MEAN_MEAN_REL_RR', 'SD2_LF', 'HR_LF', 'HR_HF', 'HF_VLF',
#        'subject id', 'SSSQ Label', 'condition label'],
#       dtype='object')

# %%
extractedDf = num_df.drop(num_df[num_df['condition label'] == 1].index)
extractedDf.reset_index(inplace = True)

# %%
extractedDf.shape
# Out:
# (112586, 66)

# %%
extractedDf.columns
# Out:
# Index(['index', 'MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD',
#        'HR', 'pNN25', 'pNN50', 'SD1', 'SD2', 'KURT', 'SKEW', 'MEAN_REL_RR',
#        'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR',
#        'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR', 'VLF', 'VLF_PCT',
#        'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF',
#        'HF_LF', 'MEAN_RR_LOG', 'MEAN_RR_SQRT', 'TP_SQRT', 'MEDIAN_REL_RR_LOG',
#        'RMSSD_REL_RR_LOG', 'SDSD_REL_RR_LOG', 'VLF_LOG', 'LF_LOG', 'HF_LOG',
#        'TP_LOG', 'LF_HF_LOG', 'RMSSD_LOG', 'SDRR_RMSSD_LOG', 'pNN25_LOG',
#        'pNN50_LOG', 'SD1_LOG', 'KURT_YEO_JONSON', 'SKEW_YEO_JONSON',
#        'MEAN_REL_RR_YEO_JONSON', 'SKEW_REL_RR_YEO_JONSON', 'LF_BOXCOX',
#        'HF_BOXCOX', 'SD1_BOXCOX', 'KURT_SQUARE', 'HR_SQRT',
#        'MEAN_RR_MEAN_MEAN_REL_RR', 'SD2_LF', 'HR_LF', 'HR_HF', 'HF_VLF',
#        'subject id', 'SSSQ Label', 'condition label'],
#       dtype='object')

# %%
extractedDf[['condition label']].value_counts()
# Out:
# condition label
# 0                  71640
# 2                  40946
# dtype: int64

# %%
extractedDf['condition label'] = extractedDf['condition label'].replace(2, 1)

# %%
extractedDf[['condition label']].value_counts()
# Out:
# condition label
# 0                  71640
# 1                  40946
# dtype: int64

# %%
max_class = extractedDf[extractedDf['condition label']== 0]
min_class = extractedDf[extractedDf['condition label']== 1]
print(max_class.shape, min_class.shape)
# Out:
# (71640, 66) (40946, 66)

# %%
# Downsampling
from sklearn.utils import resample

max_class_downsampled = resample(max_class, replace=True, n_samples=len(min_class), random_state=42)

# %%
finalDf = pd.concat([max_class_downsampled, min_class])

# %%
finalDf[['condition label']].value_counts()
# Out:
# condition label
# 0                  40946
# 1                  40946
# dtype: int64

# %%
X = finalDf.drop(['index','subject id','condition label'], axis=1)
y = finalDf['condition label']

# %%
X.columns
# Out:
# Index(['MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR',
#        'pNN25', 'pNN50', 'SD1', 'SD2', 'KURT', 'SKEW', 'MEAN_REL_RR',
#        'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR',
#        'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR', 'VLF', 'VLF_PCT',
#        'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF',
#        'HF_LF', 'MEAN_RR_LOG', 'MEAN_RR_SQRT', 'TP_SQRT', 'MEDIAN_REL_RR_LOG',
#        'RMSSD_REL_RR_LOG', 'SDSD_REL_RR_LOG', 'VLF_LOG', 'LF_LOG', 'HF_LOG',
#        'TP_LOG', 'LF_HF_LOG', 'RMSSD_LOG', 'SDRR_RMSSD_LOG', 'pNN25_LOG',
#        'pNN50_LOG', 'SD1_LOG', 'KURT_YEO_JONSON', 'SKEW_YEO_JONSON',
#        'MEAN_REL_RR_YEO_JONSON', 'SKEW_REL_RR_YEO_JONSON', 'LF_BOXCOX',
#        'HF_BOXCOX', 'SD1_BOXCOX', 'KURT_SQUARE', 'HR_SQRT',
#        'MEAN_RR_MEAN_MEAN_REL_RR', 'SD2_LF', 'HR_LF', 'HR_HF', 'HF_VLF',
#        'SSSQ Label'],
#       dtype='object')

# %%
X.shape, y.shape
# Out:
# ((81892, 63), (81892,))

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# https://www.kaggle.com/code/vaseline555/1d-cnn-for-numerical-features

# %% [markdown]
# ### 1D CNN

# %%
# https://towardsdatascience.com/feature-selection-using-random-forest-26d7b747597f

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(X), y , random_state=104, test_size=0.25)

sel = SelectFromModel(RandomForestClassifier(n_estimators = 100))
sel.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
sel.get_support()
# Out:
# array([ True,  True, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False,  True,  True, False, False,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#         True, False,  True, False, False, False, False,  True, False])

# %%
X_train = pd.DataFrame(X_train)
selected_feat= X_train.columns[(sel.get_support())]
len(selected_feat)
# Out:
# 15

# %%
print(selected_feat)
# Out:
# Int64Index([0, 1, 6, 15, 16, 17, 27, 32, 33, 36, 37, 52, 54, 56, 61], dtype='int64')

# %%
for i in selected_feat:
  print(X.columns[i])
# Out:
# MEAN_RR
# MEDIAN_RR
# HR
# SDRR_REL_RR
# RMSSD_REL_RR
# SDSD_REL_RR
# HF_PCT
# MEAN_RR_LOG
# MEAN_RR_SQRT
# RMSSD_REL_RR_LOG
# SDSD_REL_RR_LOG
# LF_BOXCOX
# SD1_BOXCOX
# HR_SQRT
# HF_VLF

# %%
pd.Series(sel.estimator_.feature_importances_.ravel()).hist()
# Out:
# <Axes: >

# %%
series_data = pd.Series(sel.estimator_.feature_importances_, index=X.columns)  # Assuming feature_names contains the names of features

# Sorting the series by importance scores
sorted_series = series_data.sort_values(ascending=False)

# Printing the features in order of their importance
for feature, importance_score in sorted_series.items():
    print(f"Feature: {feature}, Importance Score: {importance_score}")
# Out:
# Feature: HR, Importance Score: 0.09354316408644309
# Feature: MEDIAN_RR, Importance Score: 0.09039733083376852
# Feature: MEAN_RR, Importance Score: 0.07506300835900752
# Feature: HR_SQRT, Importance Score: 0.07417451930204658
# Feature: MEAN_RR_LOG, Importance Score: 0.05868061930331363
# Feature: MEAN_RR_SQRT, Importance Score: 0.05515945769869983
# Feature: SD1_BOXCOX, Importance Score: 0.029114149317684287
# Feature: SDSD_REL_RR, Importance Score: 0.024390196167138497
# Feature: RMSSD_REL_RR, Importance Score: 0.020637363216423416
# Feature: RMSSD_REL_RR_LOG, Importance Score: 0.020520890675303726
# Feature: SDSD_REL_RR_LOG, Importance Score: 0.020086697940568762
# Feature: LF_BOXCOX, Importance Score: 0.019022911971325634
# Feature: SDRR_REL_RR, Importance Score: 0.018730219552501818
# Feature: HF_VLF, Importance Score: 0.018335953239665553
# Feature: HF_PCT, Importance Score: 0.01619264689044289
# Feature: HF, Importance Score: 0.015629916852257276
# Feature: RMSSD_LOG, Importance Score: 0.014491894167361057
# Feature: SSSQ Label, Importance Score: 0.013905417356882192
# Feature: MEDIAN_REL_RR_LOG, Importance Score: 0.013899445322767632
# Feature: MEDIAN_REL_RR, Importance Score: 0.01320927032356142
# Feature: LF, Importance Score: 0.013040848641244275
# Feature: HF_LOG, Importance Score: 0.012941575063608005
# Feature: LF_LOG, Importance Score: 0.012500696199051538
# Feature: SKEW_YEO_JONSON, Importance Score: 0.012421984906450946
# Feature: SD1, Importance Score: 0.012050888804731057
# Feature: HF_NU, Importance Score: 0.011785257333636836
# Feature: LF_HF_LOG, Importance Score: 0.011128135268610785
# Feature: pNN25, Importance Score: 0.011103588582924656
# Feature: SDSD, Importance Score: 0.010440179784110905
# Feature: HF_BOXCOX, Importance Score: 0.010209637386316292
# Feature: SD1_LOG, Importance Score: 0.009774186785715944
# Feature: RMSSD, Importance Score: 0.009157441049419547
# Feature: SDRR_RMSSD_REL_RR, Importance Score: 0.008936208929320745
# Feature: HR_LF, Importance Score: 0.00867065942960167
# Feature: SKEW_REL_RR, Importance Score: 0.008601412451310903
# Feature: pNN25_LOG, Importance Score: 0.008498363185230192
# Feature: KURT_YEO_JONSON, Importance Score: 0.008286694141509737
# Feature: LF_HF, Importance Score: 0.008198038105584044
# Feature: SD2, Importance Score: 0.007369696271787563
# Feature: KURT, Importance Score: 0.007334214013406806
# Feature: SDRR, Importance Score: 0.007279203977602036
# Feature: VLF_PCT, Importance Score: 0.006648105996057941
# Feature: HF_LF, Importance Score: 0.006454108899150783
# Feature: KURT_REL_RR, Importance Score: 0.0060648451795393245
# Feature: SDRR_RMSSD, Importance Score: 0.0058999955672399875
# Feature: SKEW_REL_RR_YEO_JONSON, Importance Score: 0.005069095273871335
# Feature: SKEW, Importance Score: 0.005016203612885457
# Feature: LF_NU, Importance Score: 0.004975707248286337
# Feature: LF_PCT, Importance Score: 0.004940241123293033
# Feature: SDRR_RMSSD_LOG, Importance Score: 0.004729190777891256
# Feature: TP_SQRT, Importance Score: 0.0043714363510403455
# Feature: TP, Importance Score: 0.004261179832838777
# Feature: VLF, Importance Score: 0.004258971341450785
# Feature: SD2_LF, Importance Score: 0.003801365646328172
# Feature: HR_HF, Importance Score: 0.0033565411223267162
# Feature: pNN50, Importance Score: 0.0032522295805690583
# Feature: VLF_LOG, Importance Score: 0.003001901860762103
# Feature: pNN50_LOG, Importance Score: 0.0028307193501376855
# Feature: TP_LOG, Importance Score: 0.00271689582329206
# Feature: KURT_SQUARE, Importance Score: 0.0018484839510018822
# Feature: MEAN_REL_RR_YEO_JONSON, Importance Score: 0.0007349912228201615
# Feature: MEAN_REL_RR, Importance Score: 0.0006542970766511145
# Feature: MEAN_RR_MEAN_MEAN_REL_RR, Importance Score: 0.00019951027422789058

# %%
# df = df[["HR", "LF_BOXCOX", "MEDIAN_RR", "SD1_BOXCOX","SDRR_REL_RR", "condition label"]]

# %%
no_of_feat = len(X.columns)
no_of_feat

# %%
X.shape, y.shape
# Out:
# ((81892, 5), (81892,))

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(X), y , random_state=104, test_size=0.25)

X_train = X_train.reshape(-1, no_of_feat, 1)
X_test = X_test.reshape(-1, no_of_feat, 1)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (61419, 5, 1) (20473, 5, 1) (61419,) (20473,)

# %%
del model
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# Create a 1D CNN model for binary classification
model = Sequential()

# Add 1D convolutional layers
model.add(Conv1D(name = "Conv1", filters=32, kernel_size=1, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(MaxPooling1D(name = "MaxPool1", pool_size=1))
model.add(Conv1D(name = "Conv2", filters=64, kernel_size=1, activation='relu'))
# model.add(MaxPooling1D(name = "MaxPool2", pool_size=1))
model.add(Conv1D(name = "Conv3", filters=128, kernel_size=1, activation='relu'))
# model.add(MaxPooling1D(name = "MaxPool3", pool_size=1))
model.add(Conv1D(name = "Conv4", filters=64, kernel_size=1, activation='relu'))
model.add(MaxPooling1D(name = "MaxPool4", pool_size=2))


# Flatten the output for fully connected layers
model.add(Flatten(name = "Flatten"))

# Add dense layers
model.add(Dense(32, activation='relu', name = "Dense1"))
# model.add(Dropout(0.5))  # Optional dropout layer to prevent overfitting
model.add(Dense(1, activation='sigmoid', name = "Output"))  # Output layer with sigmoid activation for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1 (Conv1D)              (None, 5, 32)             64
#
#  Conv2 (Conv1D)              (None, 5, 64)             2112
#
#  Conv3 (Conv1D)              (None, 5, 128)            8320
#
#  Conv4 (Conv1D)              (None, 5, 64)             8256
#
#  MaxPool4 (MaxPooling1D)     (None, 2, 64)             0
#
#  Flatten (Flatten)           (None, 128)               0
#
#  Dense1 (Dense)              (None, 32)                4128
#
#  Output (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 22913 (89.50 KB)
# Trainable params: 22913 (89.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
 # Train the model with your dataset
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 1536/1536 [==============================] - 11s 6ms/step - loss: 0.5858 - acc: 0.7191 - val_loss: 0.4480 - val_acc: 0.7526
# Epoch 2/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.4585 - acc: 0.7656 - val_loss: 0.4695 - val_acc: 0.7905
# Epoch 3/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.3788 - acc: 0.8203 - val_loss: 0.3187 - val_acc: 0.8580
# Epoch 4/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.3236 - acc: 0.8470 - val_loss: 0.2763 - val_acc: 0.8768
# Epoch 5/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.2569 - acc: 0.8900 - val_loss: 0.2253 - val_acc: 0.9263
# Epoch 6/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.2055 - acc: 0.9251 - val_loss: 0.1663 - val_acc: 0.9453
# Epoch 7/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.1817 - acc: 0.9352 - val_loss: 0.1910 - val_acc: 0.9253
# Epoch 8/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.1636 - acc: 0.9408 - val_loss: 0.1448 - val_acc: 0.9481
# Epoch 9/100
# 1536/1536 [==============================] - 9s 6ms/step - loss: 0.1509 - acc: 0.9453 - val_loss: 0.1405 - val_acc: 0.9515
# Epoch 10/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.1460 - acc: 0.9462 - val_loss: 0.1087 - val_acc: 0.9642
# Epoch 11/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.1308 - acc: 0.9529 - val_loss: 0.1277 - val_acc: 0.9537
# Epoch 12/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.1239 - acc: 0.9546 - val_loss: 0.1036 - val_acc: 0.9633
# Epoch 13/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.1149 - acc: 0.9581 - val_loss: 0.0977 - val_acc: 0.9651
# Epoch 14/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.1123 - acc: 0.9589 - val_loss: 0.0876 - val_acc: 0.9683
# Epoch 15/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.1064 - acc: 0.9609 - val_loss: 0.0929 - val_acc: 0.9652
# Epoch 16/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.1014 - acc: 0.9630 - val_loss: 0.1063 - val_acc: 0.9653
# Epoch 17/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.1036 - acc: 0.9615 - val_loss: 0.0803 - val_acc: 0.9735
# Epoch 18/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0988 - acc: 0.9627 - val_loss: 0.0811 - val_acc: 0.9704
# Epoch 19/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0940 - acc: 0.9658 - val_loss: 0.0888 - val_acc: 0.9651
# Epoch 20/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0918 - acc: 0.9656 - val_loss: 0.1597 - val_acc: 0.9383
# Epoch 21/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0919 - acc: 0.9652 - val_loss: 0.0805 - val_acc: 0.9743
# Epoch 22/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0871 - acc: 0.9681 - val_loss: 0.0655 - val_acc: 0.9781
# Epoch 23/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0892 - acc: 0.9669 - val_loss: 0.0653 - val_acc: 0.9775
# Epoch 24/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.0851 - acc: 0.9688 - val_loss: 0.0834 - val_acc: 0.9673
# Epoch 25/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0819 - acc: 0.9712 - val_loss: 0.0746 - val_acc: 0.9713
# Epoch 26/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0833 - acc: 0.9699 - val_loss: 0.0724 - val_acc: 0.9751
# Epoch 27/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0800 - acc: 0.9713 - val_loss: 0.0646 - val_acc: 0.9767
# Epoch 28/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0780 - acc: 0.9715 - val_loss: 0.0589 - val_acc: 0.9812
# Epoch 29/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0803 - acc: 0.9706 - val_loss: 0.0650 - val_acc: 0.9765
# Epoch 30/100
# 1536/1536 [==============================] - 8s 6ms/step - loss: 0.0763 - acc: 0.9732 - val_loss: 0.0779 - val_acc: 0.9716
# Epoch 31/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0733 - acc: 0.9736 - val_loss: 0.0792 - val_acc: 0.9718
# Epoch 32/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0759 - acc: 0.9728 - val_loss: 0.0660 - val_acc: 0.9778
# Epoch 33/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.0741 - acc: 0.9724 - val_loss: 0.0683 - val_acc: 0.9779
# Epoch 34/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0744 - acc: 0.9721 - val_loss: 0.0614 - val_acc: 0.9793
# Epoch 35/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0725 - acc: 0.9728 - val_loss: 0.0642 - val_acc: 0.9795
# Epoch 36/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0695 - acc: 0.9746 - val_loss: 0.0731 - val_acc: 0.9745
# Epoch 37/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0716 - acc: 0.9729 - val_loss: 0.0713 - val_acc: 0.9721
# Epoch 38/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0695 - acc: 0.9739 - val_loss: 0.0811 - val_acc: 0.9696
# Epoch 39/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.0694 - acc: 0.9742 - val_loss: 0.0635 - val_acc: 0.9742
# Epoch 40/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0678 - acc: 0.9745 - val_loss: 0.0600 - val_acc: 0.9757
# Epoch 41/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.0666 - acc: 0.9741 - val_loss: 0.0825 - val_acc: 0.9638
# Epoch 42/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0662 - acc: 0.9747 - val_loss: 0.0544 - val_acc: 0.9812
# Epoch 43/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0657 - acc: 0.9751 - val_loss: 0.0661 - val_acc: 0.9769
# Epoch 44/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0659 - acc: 0.9742 - val_loss: 0.0737 - val_acc: 0.9714
# Epoch 45/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0634 - acc: 0.9749 - val_loss: 0.0681 - val_acc: 0.9736
# Epoch 46/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0642 - acc: 0.9751 - val_loss: 0.0506 - val_acc: 0.9838
# Epoch 47/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0627 - acc: 0.9757 - val_loss: 0.0603 - val_acc: 0.9779
# Epoch 48/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0624 - acc: 0.9757 - val_loss: 0.0485 - val_acc: 0.9818
# Epoch 49/100
# 1536/1536 [==============================] - 9s 6ms/step - loss: 0.0621 - acc: 0.9761 - val_loss: 0.0783 - val_acc: 0.9703
# Epoch 50/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0612 - acc: 0.9760 - val_loss: 0.0710 - val_acc: 0.9704
# Epoch 51/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0634 - acc: 0.9754 - val_loss: 0.0471 - val_acc: 0.9835
# Epoch 52/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0609 - acc: 0.9767 - val_loss: 0.0702 - val_acc: 0.9758
# Epoch 53/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0582 - acc: 0.9768 - val_loss: 0.0439 - val_acc: 0.9825
# Epoch 54/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0620 - acc: 0.9757 - val_loss: 0.0534 - val_acc: 0.9798
# Epoch 55/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0576 - acc: 0.9772 - val_loss: 0.0495 - val_acc: 0.9816
# Epoch 56/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0599 - acc: 0.9763 - val_loss: 0.0520 - val_acc: 0.9828
# Epoch 57/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0575 - acc: 0.9774 - val_loss: 0.0470 - val_acc: 0.9820
# Epoch 58/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.0595 - acc: 0.9769 - val_loss: 0.0490 - val_acc: 0.9824
# Epoch 59/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0577 - acc: 0.9783 - val_loss: 0.0774 - val_acc: 0.9704
# Epoch 60/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0571 - acc: 0.9782 - val_loss: 0.0463 - val_acc: 0.9827
# Epoch 61/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0569 - acc: 0.9775 - val_loss: 0.0452 - val_acc: 0.9834
# Epoch 62/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0572 - acc: 0.9776 - val_loss: 0.0447 - val_acc: 0.9862
# Epoch 63/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0573 - acc: 0.9776 - val_loss: 0.0528 - val_acc: 0.9788
# Epoch 64/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0567 - acc: 0.9784 - val_loss: 0.0412 - val_acc: 0.9820
# Epoch 65/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0554 - acc: 0.9785 - val_loss: 0.0474 - val_acc: 0.9803
# Epoch 66/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0562 - acc: 0.9779 - val_loss: 0.0667 - val_acc: 0.9731
# Epoch 67/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0546 - acc: 0.9784 - val_loss: 0.0599 - val_acc: 0.9770
# Epoch 68/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0562 - acc: 0.9784 - val_loss: 0.0558 - val_acc: 0.9782
# Epoch 69/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0545 - acc: 0.9788 - val_loss: 0.0432 - val_acc: 0.9830
# Epoch 70/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0543 - acc: 0.9781 - val_loss: 0.0535 - val_acc: 0.9781
# Epoch 71/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0552 - acc: 0.9787 - val_loss: 0.0441 - val_acc: 0.9825
# Epoch 72/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0528 - acc: 0.9791 - val_loss: 0.0455 - val_acc: 0.9836
# Epoch 73/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0541 - acc: 0.9789 - val_loss: 0.0510 - val_acc: 0.9777
# Epoch 74/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0546 - acc: 0.9785 - val_loss: 0.0379 - val_acc: 0.9856
# Epoch 75/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0521 - acc: 0.9798 - val_loss: 0.0421 - val_acc: 0.9840
# Epoch 76/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0509 - acc: 0.9801 - val_loss: 0.0418 - val_acc: 0.9842
# Epoch 77/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0528 - acc: 0.9795 - val_loss: 0.0436 - val_acc: 0.9837
# Epoch 78/100
# 1536/1536 [==============================] - 7s 4ms/step - loss: 0.0542 - acc: 0.9786 - val_loss: 0.0446 - val_acc: 0.9810
# Epoch 79/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0541 - acc: 0.9788 - val_loss: 0.0456 - val_acc: 0.9802
# Epoch 80/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0492 - acc: 0.9804 - val_loss: 0.0435 - val_acc: 0.9844
# Epoch 81/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0543 - acc: 0.9787 - val_loss: 0.0410 - val_acc: 0.9840
# Epoch 82/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0511 - acc: 0.9796 - val_loss: 0.0502 - val_acc: 0.9795
# Epoch 83/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0499 - acc: 0.9801 - val_loss: 0.0421 - val_acc: 0.9836
# Epoch 84/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0504 - acc: 0.9802 - val_loss: 0.0373 - val_acc: 0.9862
# Epoch 85/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0509 - acc: 0.9802 - val_loss: 0.0426 - val_acc: 0.9836
# Epoch 86/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0493 - acc: 0.9805 - val_loss: 0.0554 - val_acc: 0.9778
# Epoch 87/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0467 - acc: 0.9813 - val_loss: 0.0475 - val_acc: 0.9796
# Epoch 88/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0519 - acc: 0.9804 - val_loss: 0.0391 - val_acc: 0.9840
# Epoch 89/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0495 - acc: 0.9808 - val_loss: 0.0423 - val_acc: 0.9845
# Epoch 90/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0493 - acc: 0.9800 - val_loss: 0.0381 - val_acc: 0.9852
# Epoch 91/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0483 - acc: 0.9814 - val_loss: 0.0472 - val_acc: 0.9823
# Epoch 92/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0474 - acc: 0.9814 - val_loss: 0.0425 - val_acc: 0.9847
# Epoch 93/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0479 - acc: 0.9811 - val_loss: 0.0411 - val_acc: 0.9840
# Epoch 94/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0484 - acc: 0.9810 - val_loss: 0.0391 - val_acc: 0.9863
# Epoch 95/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0494 - acc: 0.9801 - val_loss: 0.0463 - val_acc: 0.9794
# Epoch 96/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0482 - acc: 0.9810 - val_loss: 0.0500 - val_acc: 0.9815
# Epoch 97/100
# 1536/1536 [==============================] - 7s 5ms/step - loss: 0.0488 - acc: 0.9810 - val_loss: 0.0480 - val_acc: 0.9802
# Epoch 98/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0478 - acc: 0.9819 - val_loss: 0.0423 - val_acc: 0.9850
# Epoch 99/100
# 1536/1536 [==============================] - 8s 5ms/step - loss: 0.0467 - acc: 0.9817 - val_loss: 0.0403 - val_acc: 0.9839
# Epoch 100/100
# 1536/1536 [==============================] - 6s 4ms/step - loss: 0.0454 - acc: 0.9822 - val_loss: 0.0363 - val_acc: 0.9866

# %%
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(history.history['acc'], label='train_acc')
plt.plot(history.history['val_acc'], label='val_acc')
plt.legend(loc='upper right')
plt.show()

# %%
result = model.evaluate(X_test, y_test)
print('Accuracy:', result[1])
# Out:
# 640/640 [==============================] - 1s 2ms/step - loss: 0.0391 - acc: 0.9856
# Accuracy: 0.9855907559394836

# %%
y_pred = model.predict(X_test)
# Out:
# 640/640 [==============================] - 1s 2ms/step

# %%
y_pred
# Out:
# array([[1.0638774e-15],
#        [9.5494417e-04],
#        [9.9953991e-01],
#        ...,
#        [1.0000000e+00],
#        [1.3703511e-08],
#        [5.1124523e-05]], dtype=float32)

# %%
y_test
# Out:
# 29778    0
# 60701    0
# 90806    1
# 71555    1
# 38341    1
#         ..
# 17378    1
# 81597    0
# 661      1
# 46957    0
# 38721    0
# Name: condition label, Length: 20473, dtype: int64

# %%
cm = tf.math.confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %%
print(cm)
# Out:
# tf.Tensor(
# [[10202     0]
#  [ 6017  4254]], shape=(2, 2), dtype=int32)

# %%
precision = cm[1][1]/(cm[1][1]+cm[1][0])
recall = cm[1][1]/(cm[1][1]+cm[0][1])
f1 = (2*precision*recall)/(recall+precision)
print(precision, recall, f1)
# Out:
# tf.Tensor(0.41417583487489046, shape=(), dtype=float64) tf.Tensor(1.0, shape=(), dtype=float64) tf.Tensor(0.5857487091222031, shape=(), dtype=float64)

# %%
98.55
